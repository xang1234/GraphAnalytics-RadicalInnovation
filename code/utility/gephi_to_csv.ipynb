# %%
# location of input files
graph_dir = 'C:/Users/U/Documents/BigData/'
#graph_dir = './'

# %%
import numpy as np
import pandas as pd
import os
import networkx as nx

# %%
pd.options.display.max_rows = 8

# %%
gephi_input_file = 'ML Extended.gexf'
Graph = nx.read_gexf(graph_dir + gephi_input_file)

# %%
ML_df = pd.DataFrame([i[1] for i in Graph.nodes(data=True)], index=[i[0] for i in Graph.nodes(data=True)])
ML_df.index.name = 'id'
ML_df.reset_index(inplace=True)
display(ML_df)
ML_df.to_csv(graph_dir + gephi_input_file + "_nodes.csv")
# Out:
#                                               id  Year  \
# 0       7a14e184b237809e370b82e9180beb8564fe396f  1999
# 1       d010e1f7f3bdf43efaf27a6eba193ce7c2b877d9  1997
# 2       d57bdcec0842be372609f3fcaa165711aede5cc9  2010
# 3       d86fbc7af1ca64440477625648179d21f39db501  2011
# ...                                          ...   ...
# 176512  faad3491ecea98c44ca84edd83a64f1a73e95091  2002
# 176513  6ed4f9343ea8110aa63ec4b891176306014d412f  2014
# 176514  521c17db81157333e0992479659092f30681eaee  2003
# 176515  6d753ad315d363413233934a1ae0f2a02da37698  1993
#
#                                                   authors  \
# 0       [{'name': 'Nick Barnes', 'ids': ['1712576']}, ...
# 1       [{'name': 'Antonio Brogi', 'ids': ['8239224']}...
# 2       [{'name': 'Dimitrios Pantazis', 'ids': ['81523...
# 3       [{'name': 'Shelly Levy-Tzedek', 'ids': ['30604...
# ...                                                   ...
# 176512  [{'name': 'Dietrich Wettschereck', 'ids': ['17...
# 176513  [{'name': 'Ahmet Dogan', 'ids': ['2106452']}, ...
# 176514  [{'name': 'Hans-Joachim Böhme', 'ids': ['26337...
# 176515  [{'name': 'Akira Orimo', 'ids': ['5873774']}, ...
#
#                                               journalName  \
# 0                                                  IJPRAI
# 1                                     Theor. Comput. Sci.
# 2                                              NeuroImage
# 3                                 Brain research bulletin
# ...                                                   ...
# 176512                                                nan
# 176513                       J. Intelligent Manufacturing
# 176514                    Robotics and Autonomous Systems
# 176515  Rinsho byori. The Japanese journal of clinical...
#
#                                                keyPhrases  \
# 0       ['Shading', 'Object Recognition', 'Light Sourc...
# 1       ['Negation', 'Proof Procedure', 'Abduction', '...
# 2       ['Freesurfer', 'Registration', 'Landmark', 'RO...
# 3       ['Ing', 'Movement Type', 'Switching', 'LIMb', ...
# ...                                                   ...
# 176512                                                 []
# 176513                                                 []
# 176514  ['Human-machine Interaction', 'Interaction Cyc...
# 176515                                                 []
#
#                                            label  \
# 0       7a14e184b237809e370b82e9180beb8564fe396f
# 1       d010e1f7f3bdf43efaf27a6eba193ce7c2b877d9
# 2       d57bdcec0842be372609f3fcaa165711aede5cc9
# 3       d86fbc7af1ca64440477625648179d21f39db501
# ...                                          ...
# 176512  faad3491ecea98c44ca84edd83a64f1a73e95091
# 176513  6ed4f9343ea8110aa63ec4b891176306014d412f
# 176514  521c17db81157333e0992479659092f30681eaee
# 176515  6d753ad315d363413233934a1ae0f2a02da37698
#
#                                                     title
# 0                      Knowledge-Based Shape-From Shading
# 1       A Unifying View for Logic Programming with Non...
# 2       Comparison of landmark-based and automatic met...
# 3       Early switching between movement types: indica...
# ...                                                   ...
# 176512                A KDDSE-independent PMML Visualizer
# 176513  Analyzing and comparing the AES architectures ...
# 176514  An approach to multi-modal human-machine inter...
# 176515  [Analysis of the variations of clinical test d...
#
# [176516 rows x 7 columns]

# %%
edges = Graph.edges(data=True)
edge_df = pd.DataFrame([i[2] for i in edges], index=[[i[0] for i in edges], [i[1] for i in edges]])
edge_df.index.names = ['id_0', 'id_1']
edge_df.reset_index(inplace=True)
display(edge_df)
edge_df.to_csv(graph_dir + gephi_input_file + "_edges.csv")
# Out:
#                                              id_0  \
# 0        7a14e184b237809e370b82e9180beb8564fe396f
# 1        7a14e184b237809e370b82e9180beb8564fe396f
# 2        7a14e184b237809e370b82e9180beb8564fe396f
# 3        d010e1f7f3bdf43efaf27a6eba193ce7c2b877d9
# ...                                           ...
# 1142692  521c17db81157333e0992479659092f30681eaee
# 1142693  521c17db81157333e0992479659092f30681eaee
# 1142694  521c17db81157333e0992479659092f30681eaee
# 1142695  521c17db81157333e0992479659092f30681eaee
#
#                                              id_1  Year       id
# 0        1f68c631ddbf84da95383adae87f25f2694407ae  1999        0
# 1        2712ece2c534b59607c3251728c8de702e0f2347  1999        1
# 2        0d3d7ffbb7355faf4d3eefd7fd97194d6d84ce93  1999        2
# 3        a0d3f4e671fb785304a059aabe343fc38a603f50  1997        3
# ...                                           ...   ...      ...
# 1142692  277f41dafb87b9557f6a05be86c10bcc5440a094  2003  1142692
# 1142693  19baaee177081e0021a4910c6280d4378f1d933d  2003  1142693
# 1142694  6182e6c1716caef9008330c693f20bec58568de9  2003  1142694
# 1142695  f4734e7a8e2a486ecb628d0ce622be553b14f4aa  2003  1142695
#
# [1142696 rows x 4 columns]
